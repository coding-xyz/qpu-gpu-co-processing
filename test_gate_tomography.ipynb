# %%
from src.tomography import run_cz_tomography, print_result, plot_chi_3d
import numpy as np

data = np.load('data/tomography_data/QPT2Q_20260127111426.qdat', allow_pickle=True)['data'][-1]
res = run_cz_tomography(data)
print_result(res)
# Out:
# PTM basis order:
# ['II', 'IX', 'IY', 'IZ', 'XI', 'XX', 'XY', 'XZ', 'YI', 'YX', 'YY', 'YZ', 'ZI', 'ZX', 'ZY', 'ZZ']
#
# Fidelity to bare CZ:
#   process fidelity      = 0.99085192
#   average gate fidelity = 0.99268153
#
# Optimized local-Z fidelity to bare CZ:
#   phi1                  = -0.03490659
#   phi2                  = 0.03490659
#   process fidelity      = 0.99169268
#   average gate fidelity = 0.99335415
#
# Global RMS residual     = 1.43898737e-02
#
# Example output state for input (2, 2) [Y/2, Y/2]:
# [[ 0.27359+0.j       0.27725-0.01079j  0.30323-0.03568j -0.25195-0.00524j]
#  [ 0.27725+0.01079j  0.24995+0.j       0.24173+0.01042j -0.28339+0.03293j]
#  [ 0.30323+0.03568j  0.24173-0.01042j  0.24402+0.j      -0.25835+0.00431j]
#  [-0.25195+0.00524j -0.28339-0.03293j -0.25835-0.00431j  0.23243+0.j     ]]

# %%
plot_chi_3d(res)
# Out:
# d:\GitHub\qpu-gpu-co-processing\src\tomography\gate_tomography.py:598: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
